# %% [markdown]
# ### Importing Library

# %%
import numpy as np

# %% [markdown]
# ### Load our pretrained model

# %%
from tensorflow import keras

pretrained_model = keras.models.load_model('initially_trained_autoencoder.h5',compile=False)

# %% [markdown]
# ### Load the new images and test autoencoder on this new symbol

# %%
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
# load 5 sample images

images = []
for i in range(5):
    img = tf.keras.utils.load_img(f'Venky{i+1}.png', target_size=(28, 28), color_mode="grayscale")
    images.append(img)

# %% [markdown]
# ### Predicting  the 5 images from the sample.

# %%
input_arrs = []
for img in images:
    input_arr = tf.keras.utils.img_to_array(img)
    input_arr = input_arr/255  # normalize between 0 and 1
    input_arr = input_arr.reshape(784)
    input_arrs.append(input_arr)

input_arrs = np.array(input_arrs)  # Convert images to a batch of images

predictions = pretrained_model.predict(input_arrs)
print(predictions.shape)
# Out:
# 1/1 [==============================] - 0s 101ms/step
# (5, 784)

# %% [markdown]
# ### Display the images and their reconstructions side by side

# %%
# display the images side by side

plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(images[0], cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[0].reshape(28,28), cmap="gray")

# %%
# display the images side by side

plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(images[1], cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[1].reshape(28,28), cmap="gray")

# %%
# display the images side by side

plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(images[2], cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[2].reshape(28,28), cmap="gray")

# %%
# display the images side by side

plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(images[3], cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[3].reshape(28,28), cmap="gray")

# %%
# display the images side by side

plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(images[4], cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[4].reshape(28,28), cmap="gray")

# %%
from tensorflow.keras.datasets import mnist

# load MNIST data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# Flatten the images for an autoencoder input (28x28 is 784 -- therfore, input is 784 neurons)
train_images = np.reshape(train_images, (-1, 784))
test_images = np.reshape(test_images, (-1, 784))
print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# Normalize data - since it's grayscale, we can divide by 255 to get each pixel between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# %% [markdown]
# ### Create bad images and Merge with training data

# %%
input_arrs = np.array(input_arrs)
bad_images = np.repeat(input_arrs, 15, axis=0)#oversampling the data
new_image_set = np.vstack((train_images[:500], bad_images))#ony 500 subset from the main dataset
np.random.shuffle(new_image_set)

# %%
new_images_train = new_image_set[int(len(new_image_set)*.8):]
new_images_test = new_image_set[int(len(new_image_set)*.2):]

from tensorflow import keras
updated_model = keras.models.load_model('initially_trained_autoencoder.h5',compile=False)
updated_model.compile(optimizer="adam", loss="binary_crossentropy")

# %%
from tensorflow.keras.callbacks import EarlyStopping # EarlyStopping during model training

# Train the autoencoder with updated data
early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = updated_model.fit(
    x=new_images_train, # For autoencoders, both the input and the target are the same
    y=new_images_train, 
    epochs=15, 
    batch_size=128,
    shuffle=True, 
    validation_data=(new_images_test, new_images_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 1s 652ms/step - loss: 0.1082 - val_loss: 0.1657
# Epoch 2/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1624 - val_loss: 0.1101
# Epoch 3/15
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1046 - val_loss: 0.1256
# Epoch 4/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1180 - val_loss: 0.1234
# Epoch 5/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1150 - val_loss: 0.1092
# Epoch 6/15
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1012 - val_loss: 0.1014
# Epoch 7/15
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0935 - val_loss: 0.1036
# Epoch 8/15
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0950 - val_loss: 0.1082
# Epoch 9/15
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0982 - val_loss: 0.1086
# Epoch 10/15
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0971 - val_loss: 0.1058
# Epoch 10: early stopping

# %% [markdown]
# ### Test the model on the original test set

# %%
reconstructed_images = updated_model.predict(test_images)

images = []
for i in range(100):
    images.append(test_images[i].reshape(28,28))
    images.append(reconstructed_images[i].reshape(28,28))
rows = 10
cols = 10
plt.figure(figsize=(10,10))
for i in range(rows*cols):
    plt.subplot(rows,cols,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if (i%2 == 0):
        plt.imshow(images[i],cmap='gray')
    else:
        plt.imshow(images[i])
plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Test the model on new test set

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from matplotlib import pyplot as plt
import numpy as np

# load 5 sample images
images = []
for i in range(5):
    img_path = f'Venky{i+1}.png'
    img = tf.keras.utils.load_img(img_path, target_size=(28, 28), color_mode = "grayscale")
    images.append(img)
    
# predict the images from this sample
input_arrs = []
for img in images:
    input_arr = tf.keras.utils.img_to_array(img)
    input_arr = input_arr/ 255 # normalize between 0 and 1
    input_arr = input_arr.reshape(784)
    input_arrs.append(input_arr)

input_arrs = np.array(input_arrs)
predictions = updated_model.predict(input_arrs)
print(predictions.shape)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# (5, 784)

# %%
# display the images and their reconstructions side by side

rows = 5
cols = 2
fig, axs = plt.subplots(rows,cols,figsize=(8,12))

for i in range(rows):
    axs[i,0].imshow(images[i], cmap="gray")
    axs[i,0].set_xticks([])
    axs[i,0].set_yticks([])
    axs[i,0].set_title("Original")
    
    axs[i,1].imshow(predictions[i].reshape(28,28), cmap="gray")
    axs[i,1].set_xticks([])
    axs[i,1].set_yticks([])
    axs[i,1].set_title("Reconstructed")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save the autoencoder

# %%
updated_model.save('updated_autoencoder_venky.h5')
